# %%
from ultralytics import YOLO

# Ladda en grundmodell av YOLO26 (vi väljer 'n' för nano, vilket brukar vara snabbast att träna)
model = YOLO('runs\detect\output2/train\weights/best.pt') 

# Starta träningen
results = model.train(
    data='./data.yaml', # Uppdatera till din faktiska sökväg
    epochs=50,                        # Börja med 50 epoker för att se hur modellen lär sig
    imgsz=640,                        # Standardstorlek för bilderna
    batch=16,                         # Antal bilder som processas samtidigt
    project='./output2',               # Namnet på mappen där resultaten sparas
    device='cuda'                     # Ändra till '0' eller 'cuda' om du har en dedikerad GPU
)
# Out:
# Ultralytics 8.4.21  Python-3.11.14 torch-2.10.0+cu130 CUDA:0 (NVIDIA GeForce RTX 4070 Ti SUPER, 16375MiB)
# ...

# %%
# Andra hyperparametrar

from ultralytics import YOLO

# Ladda en grundmodell av YOLO26 (vi väljer 'n' för nano, vilket brukar vara snabbast att träna)
model = YOLO("yolo26n.pt") 

results = model.train(
    data='./data.yaml',
    epochs=100,                        
    imgsz=640,                       
    batch=8,         
    workers=2,         
    project='./output2',               
    device='cuda',                 
    patience=15, 
    flipud=0.2, 
    mixup=0.2, 
    copy_paste=0.1, 
    degrees=15.0,
    shear=5.0, 
    dropout=0.2, 
    label_smoothing=0.1 
)
# Out:
# WARNING 'label_smoothing' is deprecated and will be removed in the future.
# Ultralytics 8.4.21  Python-3.11.14 torch-2.10.0+cu130 CUDA:0 (NVIDIA GeForce RTX 4070 Ti SUPER, 16375MiB)
# ...
